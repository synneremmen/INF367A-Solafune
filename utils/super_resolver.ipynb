# %%
import remote_sensing_processor as rsp
from glob import glob

# %%
sentinel2_imgs = ["../data/superres/train_2_SAFE.zip"]
output_sentinels = rsp.sentinel2(sentinel2_imgs, normalize=False, sen2cor=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 2
#       1 sentinel2_imgs = ["../data/superres/train_2_SAFE.zip"]
# ----> 2 output_sentinels = rsp.sentinel2(sentinel2_imgs, normalize=False, sen2cor=False)
#
# File c:\Users\chriz\miniconda3\envs\solafuneenv\Lib\site-packages\remote_sensing_processor\__init__.py:159, in sentinel2(archives, sen2cor, upscale, resample, crs, cloud_mask, clip, normalize)
#     157 paths = []
#     158 for archive in archives:
# --> 159     path = unzip_sentinel(archive)
#     160     path1 = glob(path + '/*/')[0]
#     161     if sen2cor == True:
#
# File c:\Users\chriz\miniconda3\envs\solafuneenv\Lib\site-packages\remote_sensing_processor\unzip\unzip.py:9, in unzip_sentinel(archive)
#       7     path = archive.replace('.zip', '/')
#       8     if os.path.exists(path):
# ----> 9         shutil.rmtree(path)
# ...

# %%
import rasterio
import matplotlib.pyplot as plt
import numpy as np

# %%
with rasterio.open("../data/superres/train_0_SAFE/train_0.SAFE/GRANULE/L2A_T31UFT_A012345_20250101T103021/IMG_DATA/R60m/B10.tif") as src:
    band = src.read(1)
    profile = src.profile
    print(profile)
    plt.imshow(band, cmap='gray')
    plt.colorbar()
    plt.show()
# Out:
# {'driver': 'GTiff', 'dtype': 'float64', 'nodata': None, 'width': 1024, 'height': 1024, 'count': 1, 'crs': CRS.from_wkt('GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AXIS["Latitude",NORTH],AXIS["Longitude",EAST],AUTHORITY["EPSG","4326"]]'), 'transform': Affine(7.159759378336239e-05, 0.0, 111.02617783449821,
#        0.0, -7.19770944171594e-05, -2.659827023558535), 'blockxsize': 256, 'blockysize': 256, 'tiled': True, 'compress': 'lzw', 'interleave': 'band'}

# %%
with rasterio.open(output_sentinels) as src:
    band = src.read(1)
    profile = src.profile
    print(profile)
    plt.imshow(band, cmap='gray')
    plt.colorbar()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 with rasterio.open(output_sentinels) as src:
#       2     band = src.read(1)
#       3     profile = src.profile
#
# NameError: name 'output_sentinels' is not defined
